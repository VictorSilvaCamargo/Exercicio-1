# %% [markdown]
# <a href="https://colab.research.google.com/github/VictorSilvaCamargo/Exercicio-1/blob/main/4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

def num_int():
    input_valido = False
    while not input_valido:
        n_numero = input("Digite um número inteiro entre 1 e 5: ")
        if n_numero.isdigit():
            n = int(n_numero)
            if 1 <= n <= 5:
                input_valido = True
            else:
                print("Valor inválido. Tente novamente.")
        else:
            print("Valor inválido. Tente novamente.")
    
    # cria um vetor com os ângulos em radianos
    x = np.linspace(0, 2*np.pi*n, 1000)
    
    # calcula as funções trigonométricas
    y1 = np.sin(x)
    y2 = np.cos(x)
    y3 = np.tan(x)
    
    # plota os gráficos
    fig, (li1, li2, li3) = plt.subplots(3, 1, figsize=(10, 10))
    li1.plot(x, y1, color='blue')
    li1.set_title('Seno')
    li2.plot(x, y2, color='green')
    li2.set_title('Cosseno')
    li3.plot(x, y3, color='red')
    li3.set_title('Tangente')
    plt.show()

num_int()
# Out:
# Digite um número inteiro entre 1 e 5: 4
